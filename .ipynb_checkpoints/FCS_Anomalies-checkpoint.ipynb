# %% [markdown]
# # To Do
#
#
# - The FL1 vs FL3 plot should ideally be square (for the time plot it is actually handy like this but square is also ok).
#
# - I would suggest to make the dots a touch more transparent and without a line edge.
#
# - If you can actually make time linear easily that would be even much better.

# %%
# Import statements

import sys
import os
print (sys.version)

import numpy as np
import pandas as pd

import matplotlib
from matplotlib import pyplot
import matplotlib.pyplot as plt

import itertools

import fcsparser
# Out:
# 3.6.8 |Anaconda, Inc.| (default, Dec 29 2018, 19:04:46)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
def softsign(x):
    out = np.log(np.abs(x)+1)*np.sign(x)
    return out

# %% [markdown]
# # Loading data
# ### Visualise files in folder
# ### Logs and remove zeros

# %%
#path_all = ("/Volumes/DOFCM_RTFCM_archive$/srusso/")
path_all = ("/Volumes/DOFCM_RTFCM_archive$/srusso/001_River_A_Data/")

name_of_path = '001_River_A_Data'
# name_of_path = '002_Tap_A_Data'
# name_of_path = '003_Grey_Water_A_Data'
# name_of_path = '004_Grey_Water_B_Data'
# name_of_path = '005_Spring_A_Data'

#path_all = os.path.join(path_all, name_of_path+'/') 
save_path = path_all     # Destination folder to for saving text file
name_of_file = 'Labels_postproc'
completeName = os.path.join(save_path, name_of_file+".csv")

# %%
# Get all the folders in path

save_path = path_all     # Destination folder to for saving text file
name_of_file = "Labels"
completeName = os.path.join(save_path, name_of_file+".txt") 


path_dir_all = []
fold_paths = []
for name in os.listdir(path_all):
    if os.path.isdir(os.path.join(path_all, name)):
        tmp = path_all + name
        path_dir_all.append(tmp)
        fold_paths.append(name)

print(fold_paths)
# Out:
# ['2013-12-06_13-44-15_chriesbach_versuchshalle_7days_v2', '2013-12-10_12-38-21_chriesbach_versuchshalle_7days_v2', '2013-12-13_11-46-59_chriesbach_versuchshalle_7days_v2', '2013-12-09_12-55-12_chriesbach_versuchshalle_7days_v2', '2013-12-12_12-04-20_chriesbach_versuchshalle_7days_v2', '2013-12-15_11-13-28_chriesbach_versuchshalle_7days_v2', '2013-12-17_10-40-31_chriesbach_versuchshalle_7days_v2', '2013-12-08_13-11-55_chriesbach_versuchshalle_7days_v2', '2013-12-16_10-56-56_chriesbach_versuchshalle_7days_v2', '2013-12-05_14-04-54_chriesbach_versuchshalle_7days_v2', '2013-12-11_12-21-41_chriesbach_versuchshalle_7days_v2', '2013-12-07_13-28-28_chriesbach_versuchshalle_7days_v2', '2013-12-14_11-30-12_chriesbach_versuchshalle_7days_v2']

# %%
# Get data

path_dir_all = []
fold_paths = []
for name in os.listdir(path_all):
    if os.path.isdir(os.path.join(path_all, name)):
        tmp = path_all + name
        path_dir_all.append(tmp)
        fold_paths.append(name)

fold = []
data_fcs = []
file_name = []


# Get directories
for path in path_dir_all:       # enter into directories
    i=0
    file_name_tmp = []
    for file in os.listdir(path):        # enter into directory files
        if file.endswith(".fcs"):
            file_name_tmp.append(file)
            i += 1
            file_name_tmp = sorted(file_name_tmp)

    for fn in file_name_tmp:
        new_path = path + '/' + fn
        meta, data = fcsparser.parse(new_path, reformat_meta=True)
        data.columns = data.columns.astype(str)
        data_fcs.append(data)
        file_name.append(fn)
    a = [path] * i
    fold.extend(a)

# %%
########## RETRY 

Randomised = 'No'   #Randomised = 'Yes'

fold = []
data_fcs = []
file_name = []


if Randomised == 'No':
    print ("Non randomised case")
    
    # Get directories
    for path in path_dir_all:       # enter into directories
        i=0
        file_name_tmp = []
        for file in os.listdir(path):        # enter into directory files
            if file.endswith(".fcs"):
                file_name_tmp.append(file)
                i += 1
                file_name_tmp = sorted(file_name_tmp)

        for fn in file_name_tmp:
            new_path = path + '/' + fn
            meta, data = fcsparser.parse(new_path, reformat_meta=True)
            data.columns = data.columns.astype(str)
            data_fcs.append(data)
            file_name.append(fn)
        a = [path] * i
        fold.extend(a)    
    
else:
    print ("Randomised case")

    # Get directories
    for path in path_dir_all:       # enter into directories
        i=0
        file_name_tmp = []
        for file in os.listdir(path):        # enter into directory files
            if file.endswith(".fcs"):
                file_name_tmp.append(file)
                i += 1
                shuffle(file_name_tmp)

        for fn in file_name_tmp:
            new_path = path + '/' + fn
            meta, data = fcsparser.parse(new_path, reformat_meta=True)
            data.columns = data.columns.astype(str)
            data_fcs.append(data)
            file_name.append(fn)
        a = [path] * i
        fold.extend(a)

###########################################
# Out:
# Non randomised case

# %%
print('Variables:', pd.DataFrame(data_fcs[0]).keys())
sr0 = pd.DataFrame(data_fcs[0]).keys()[2]
sr1 = pd.DataFrame(data_fcs[0]).keys()[4]
print('Selected variables:',sr0,',', sr1)
# Out:
# Variables: Index(['FSC-A', 'SSC-A', 'FL1-A', 'FL2-A', 'FL3-A', 'FL4-A', 'FSC-H', 'SSC-H',
#        'FL1-H', 'FL2-H', 'FL3-H', 'FL4-H', 'Width', 'Time'],
#       dtype='object')
# Selected variables: FL1-A , FL3-A

# %%
data_copy = data_fcs.copy()

for i in range(len(file_name)):
    file_name[i] = file_name[i].split('.')[0]
       
    
# Get folder names
fold_names = []
for i in range (len(fold)):
    tmp = ((fold[i].split('/'))[-1])
    fold_names.append(tmp)
                           
data_strct = [fold, file_name]
#print(data_strct)
if len(fold) != len(data_fcs):
    print('There is an error')
    
# This is not used at the moment
data_strct_df = pd.DataFrame(
    {'Folder': fold_names,
     'File_name': file_name
    })  

#print(file_name)

# %% [markdown]
# ### Load anomaly file

# %%
data_lb = pd.read_csv(completeName, sep=",")
data_lb.drop(columns=['Unnamed: 0'], inplace = True )
data_lb.columns = ["Path","Anomaly", "Label"]
data_lb

# %%
# Fraction of anomalies
print('Fraction of anomalies:', np.count_nonzero(data_lb['Label'])/len(data_lb))
print('Labels file size:', len(data_lb))
# Out:
# Fraction of anomalies: 0.09378489021213249
# Labels file size: 2687

# %%
# Transform all anomalies types to 1
data_lb_n = data_lb.copy(deep=True)
data_lb_n['Label'] = np.where(data_lb['Label']!= 0, 1, data_lb['Label'])

# %%
print('Labels shape matches data shape:', data_lb.shape[0]==len(data_fcs))
# Out:
# Labels shape matches data shape: True

# %% [markdown]
# ### Try to plot a sample

# %%
# %matplotlib notebook

Pos0 = data_fcs[1]['FL1-A']    # Sample 0 is different
Pos1 = data_fcs[1]['FL3-A']
Pos= np.transpose([Pos0,Pos1])
X = softsign(Pos)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(X[:,0],X[:,1],alpha=0.1, color='black', linestyle='None', marker='.')
ax1.set_xlim([5, 14])
ax1.set_ylim([0, 13])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 13)

# %%
df = pd.DataFrame()
for i in range(len(data_fcs)):
    print(i)
    tmp_df = data_fcs[i].copy(deep=True)
    tmp_df.insert(loc=0, column = 'UID', value = i)
    tmp_df.insert(loc=tmp_df.shape[1], column = 'Label', value = data_lb['Label'][i])
    df = df.append(tmp_df, sort = False)

# %%
df.keys()
# Out:
# Index(['UID', 'FSC-A', 'SSC-A', 'FL1-A', 'FL2-A', 'FL3-A', 'FL4-A', 'FSC-H',
#        'SSC-H', 'FL1-H', 'FL2-H', 'FL3-H', 'FL4-H', 'Width', 'Time', 'Label'],
#       dtype='object')

# %%
uid_list = df['UID'].unique()    # unique IDs
uid_list
# Out:
# array([   0,    1,    2, ..., 2684, 2685, 2686])

# %%
#df.loc[df['UID']==990]['FL1-H']   # locate unique dataframes

# %% [markdown]
# ## Save and load files as pickle

# %%
# # Save data as pickle
import pickle

file = open(name_of_path, 'wb')   # open a file, where you want to store the data
pickle.dump(df, file, protocol=4)   # dump information to that file
file.close()   # close the file

# %%
file = open(name_of_path, 'rb')  # open a file, where you stored the pickled data
df1 = pickle.load(file)   # dump information to that file
file.close()   # close the file

# %%
df1.shape

# %%
import sys

# %%
sys.getsizeof(df1)

# %%
#del df1
